# %% [markdown]
# # SQL Assignment: Setting Up the Database Connection
# In this assignment, you will learn how to connect to a database using `SQLAlchemy` and environment variables. Follow the steps below carefully to set up the connection to your database.
#
# ### Install all libraries
# Let's start by installing all the libraries listed in `requirements.txt`:

# %%
# TODO: Run this cell to install libraries listed in `requirements.txt`
# !pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sqlalchemy==1.4.0 (from -r ../requirements.txt (line 2))
#   Downloading SQLAlchemy-1.4.0.tar.gz (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 52.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pandas==2.1.4 (from -r ../requirements.txt (line 3))
#   Downloading pandas-2.1.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting python-dotenv==0.20.0 (from -r ../requirements.txt (line 4))
#   Downloading python_dotenv-0.20.0-py3-none-any.whl.metadata (19 kB)
# Collecting psycopg2-binary==2.9.3 (from -r ../requirements.txt (line 5))
#   Downloading psycopg2-binary-2.9.3.tar.gz (380 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy>=1.18.5 (from -r ../requirements.txt (line 7))
#   Downloading numpy-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting jupyter==1.* (from -r ../requirements.txt (line 12))
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy==1.4.0->-r ../requirements.txt (line 2))
#   Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting numpy>=1.18.5 (from -r ../requirements.txt (line 7))
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.12/site-packages (from pandas==2.1.4->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas==2.1.4->-r ../requirements.txt (line 3))
#   Downloading pytz-2025.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas==2.1.4->-r ../requirements.txt (line 3))
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting notebook (from jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading notebook-7.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipykernel in /home/vscode/.local/lib/python3.12/site-packages (from jupyter==1.*->-r ../requirements.txt (line 12)) (6.29.5)
# Collecting ipywidgets (from jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting jupyterlab (from jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyterlab-4.3.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.1.4->-r ../requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (1.8.12)
# Requirement already satisfied: ipython>=7.23.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (8.32.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (1.6.0)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (24.2)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/vscode/.local/lib/python3.12/site-packages (from ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-console->jupyter==1.*->-r ../requirements.txt (line 12)) (3.0.50)
# Requirement already satisfied: pygments in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-console->jupyter==1.*->-r ../requirements.txt (line 12)) (2.19.1)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jinja2>=3.0.3 (from jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.12/site-packages (from jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12)) (69.0.3)
# Collecting beautifulsoup4 (from nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading beautifulsoup4-4.13.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting markupsafe>=2.0 (from nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading mistune-3.1.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting anyio (from httpx>=0.25.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting certifi (from httpx>=0.25.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: decorator in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (4.9.0)
# Requirement already satisfied: stack_data in /home/vscode/.local/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (0.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/vscode/.local/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (4.3.6)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting requests>=2.31 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: wcwidth in /home/vscode/.local/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter==1.*->-r ../requirements.txt (line 12)) (0.2.13)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting typing-extensions>=4.0.0 (from beautifulsoup4->nbconvert->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sniffio>=1.1 (from anyio->httpx>=0.25.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/vscode/.local/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (0.8.4)
# Collecting attrs>=22.2.0 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading attrs-25.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading referencing-0.36.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading rpds_py-0.22.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading python_json_logger-3.2.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vscode/.local/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (0.7.0)
# Collecting charset-normalizer<4,>=2 (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: executing>=1.2.0 in /home/vscode/.local/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/vscode/.local/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/vscode/.local/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter==1.*->-r ../requirements.txt (line 12)) (0.2.3)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading cffi-1.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter==1.*->-r ../requirements.txt (line 12))
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# Downloading pandas-2.1.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 59.4 MB/s eta 0:00:00
# Downloading python_dotenv-0.20.0-py3-none-any.whl (17 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 60.9 MB/s eta 0:00:00:00:01
# Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 29.2 MB/s eta 0:00:00
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jupyterlab-4.3.5-py3-none-any.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 55.2 MB/s eta 0:00:00:00:01
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading notebook-7.3.2-py3-none-any.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 51.1 MB/s eta 0:00:00:00:01
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mistune-3.1.1-py3-none-any.whl (53 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 50.3 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.13.3-py3-none-any.whl (186 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading anyio-4.8.0-py3-none-any.whl (96 kB)
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 59.2 MB/s eta 0:00:00
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
# Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading python_json_logger-3.2.1-py3-none-any.whl (14 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 32.8 MB/s eta 0:00:00
# Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rpds_py-0.22.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading cffi-1.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (479 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Building wheels for collected packages: sqlalchemy, psycopg2-binary
#   Building wheel for sqlalchemy (pyproject.toml) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.4.0-cp312-cp312-linux_x86_64.whl size=1494258 sha256=b15b03834f21768313ec418735ded9d20e1a5a53d7a29f5919d5ba8b8377dc8a
#   Stored in directory: /home/vscode/.cache/pip/wheels/a6/b1/f8/f3401c8d8cde72a608b1399e8e0277aa542a70efd4defe44a5
#   Building wheel for psycopg2-binary (pyproject.toml) ... done
#   Created wheel for psycopg2-binary: filename=psycopg2_binary-2.9.3-cp312-cp312-linux_x86_64.whl size=514421 sha256=3c0ff5a5addc4aa27ba88dcce31683222597007ce18b23d51c1c4136da2f4d72
#   Stored in directory: /home/vscode/.cache/pip/wheels/e5/80/66/0491b93bb7c2baabe083f74099f67bcd1f849d0522ef66bace
# Successfully built sqlalchemy psycopg2-binary
# Installing collected packages: webencodings, pytz, fastjsonschema, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, typing-extensions, types-python-dateutil, tinycss2, terminado, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyyaml, python-json-logger, python-dotenv, pycparser, psycopg2-binary, prometheus-client, pandocfilters, overrides, numpy, mistune, markupsafe, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, json5, idna, h11, greenlet, fqdn, defusedxml, charset-normalizer, certifi, bleach, babel, attrs, async-lru, sqlalchemy, requests, referencing, pandas, jupyter-server-terminals, jinja2, httpcore, cffi, beautifulsoup4, arrow, anyio, jsonschema-specifications, isoduration, ipywidgets, httpx, argon2-cffi-bindings, jupyter-console, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed anyio-4.8.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-25.1.0 babel-2.17.0 beautifulsoup4-4.13.3 bleach-6.2.0 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 defusedxml-0.7.1 fastjsonschema-2.21.1 fqdn-1.5.1 greenlet-3.1.1 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 idna-3.10 ipywidgets-8.1.5 isoduration-20.11.0 jinja2-3.1.5 json5-0.10.0 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-3.0.13 markupsafe-3.0.2 mistune-3.1.1 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.3.2 notebook-shim-0.2.4 numpy-1.26.4 overrides-7.7.0 pandas-2.1.4 pandocfilters-1.5.1 prometheus-client-0.21.1 psycopg2-binary-2.9.3 pycparser-2.22 python-dotenv-0.20.0 python-json-logger-3.2.1 pytz-2025.1 pyyaml-6.0.2 referencing-0.36.2 requests-2.32.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.22.3 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 sqlalchemy-1.4.0 terminado-0.18.1 tinycss2-1.4.0 types-python-dateutil-2.9.0.20241206 typing-extensions-4.12.2 tzdata-2025.1 uri-template-1.3.0 urllib3-2.3.0 webcolors-24.11.1 webencodings-0.5.1 websocket-client-1.8.0 widgetsnbextension-4.0.13
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Create a `.env` file
# 1. In the root directory of your project, you should see a file named `.env.example`. This file provides a template for setting up your database connection variables.
#
# 2. Duplicate the `.env.example` file and rename the copy to `.env`. You can do this in your terminal or file explorer.
#     - In the terminal, run the following command:
#
#         ```python
#         cp .env.example .env
#         ```
#
# 3. Open the `.env` file and modify the following line:
#
#     ```python
#     DB_NAME = '<your database name>'
#     ```
#
#     Replace `<your database name>` with the name of your custom database. For example:
#
#     ```python
#     DB_NAME = 'my_database'
#     ```
#
# 4. Save the changes to the `.env` file.

# %% [markdown]
# ### Verify Your `.env` File Setup
# 1. Run the following code cell to confirm that the environment variables in your `.env` file are being loaded correctly:

# %%
# TODO: Run this cell to import the necessary libraries and load your variables you set in your .env file
import os
from sqlalchemy import create_engine, inspect
import pandas as pd
from dotenv import load_dotenv

# Load the .env file variables
# The output of this command should be `True`
# If the output is `False`, that means you did not create a valid .env file in the root directory of this project
load_dotenv()
# Out:
# True

# %% [markdown]
# 2. If your `.env` file is set up correctly, the command should return `True`. If it returns `False`, check the following:
#
#     - Ensure the `.env` file is located in the **root directory** of your project.
#
#     - Double-check that you replaced `<your database name>` with your actual database name.
#
#     - Make sure there are no syntax errors in the `.env` file (e.g., no extra spaces or missing values).
#
# 3. You can also validate and inspect your environment variables by running the following code cell:

# %%
# Inspect the environment variables
print(os.getenv('DB_USER'))
print(os.getenv('DB_HOST'))
print(os.getenv('DB_NAME'))
print(os.getenv('DB_PASSWORD'))
# Out:
# gitpod
# localhost
# GABE
# postgres

# %% [markdown]
# ### Connecting to the Database
# Now that you have set up your `.env` file and confirmed the environment variables are loaded correctly, it’s time to establish a connection to your database using `SQLAlchemy`'s `create_engine` function.
#
# 1. Run the following code to establish a connection:

# %%
# 1) Connect to the database here using the SQLAlchemy's `create_engine`` function
# A "connection string" is basically a string containing all database credentials together.
connection_string = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}/{os.getenv('DB_NAME')}"
engine = create_engine(connection_string)
engine.connect()
print("Starting the connection...")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3112, in Engine._wrap_pool_connect(self, fn, connection)
#    3111 try:
# -> 3112     return fn()
#    3113 except dialect.dbapi.Error as e:
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:301, in Pool.connect(self)
#     294 """Return a DBAPI connection from the pool.
#     295
#     296 The connection is instrumented such that when its
#    (...)
#     299
#     300 """
# --> 301 return _ConnectionFairy._checkout(self)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:748, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     747 if not fairy:
# --> 748     fairy = _ConnectionRecord.checkout(pool)
#     750     fairy._pool = pool
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:419, in _ConnectionRecord.checkout(cls, pool)
#     417 @classmethod
#     418 def checkout(cls, pool):
# --> 419     rec = pool._do_get()
#     420     try:
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:144, in QueuePool._do_get(self)
#     143 except:
# --> 144     with util.safe_reraise():
#     145         self._dec_overflow()
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:142, in QueuePool._do_get(self)
#     141 try:
# --> 142     return self._create_connection()
#     143 except:
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:247, in Pool._create_connection(self)
#     245 """Called by subclasses to create a new ConnectionRecord."""
# --> 247 return _ConnectionRecord(self)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:362, in _ConnectionRecord.__init__(self, pool, connect)
#     361 if connect:
# --> 362     self.__connect(first_connect_check=True)
#     363 self.finalize_callback = deque()
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:597, in _ConnectionRecord.__connect(self, first_connect_check)
#     596 except Exception as e:
# --> 597     with util.safe_reraise():
#     598         pool.logger.debug("Error on connect(): %s", e)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:592, in _ConnectionRecord.__connect(self, first_connect_check)
#     591 self.starttime = time.time()
# --> 592 connection = pool._invoke_creator(self)
#     593 pool.logger.debug("Created new connection %r", connection)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/create.py:576, in create_engine.<locals>.connect(connection_record)
#     575             return connection
# --> 576 return dialect.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:548, in DefaultDialect.connect(self, *cargs, **cparams)
#     546 def connect(self, *cargs, **cparams):
#     547     # inherits the docstring from interfaces.Dialect.connect
# --> 548     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "GABE" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 5
#       3 connection_string = f"postgresql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}/{os.getenv('DB_NAME')}"
#       4 engine = create_engine(connection_string)
# ----> 5 engine.connect()
#       6 print("Starting the connection...")
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3066, in Engine.connect(self, close_with_result)
#    3051 def connect(self, close_with_result=False):
#    3052     """Return a new :class:`_engine.Connection` object.
#    3053
#    3054     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3063
#    3064     """
# -> 3066     return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:91, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      86     self._has_events = _branch_from._has_events
#      87 else:
#      88     self._dbapi_connection = (
#      89         connection
#      90         if connection is not None
# ---> 91         else engine.raw_connection()
#      92     )
#      94     self._transaction = self._nested_transaction = None
#      95     self.__savepoint_seq = 0
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3145, in Engine.raw_connection(self, _connection)
#    3123 def raw_connection(self, _connection=None):
#    3124     """Return a "raw" DBAPI connection from the connection pool.
#    3125
#    3126     The returned object is a proxied version of the DBAPI
#    (...)
#    3143
#    3144     """
# -> 3145     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3115, in Engine._wrap_pool_connect(self, fn, connection)
#    3113 except dialect.dbapi.Error as e:
#    3114     if connection is None:
# -> 3115         Connection._handle_dbapi_exception_noconnection(
#    3116             e, dialect, self
#    3117         )
#    3118     else:
#    3119         util.raise_(
#    3120             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3121         )
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:2003, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2001     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2002 elif should_wrap:
# -> 2003     util.raise_(
#    2004         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005     )
#    2006 else:
#    2007     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     195     exception.__cause__ = replace_context
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#     203     del exception, replace_context, from_, with_traceback
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/base.py:3112, in Engine._wrap_pool_connect(self, fn, connection)
#    3110 dialect = self.dialect
#    3111 try:
# -> 3112     return fn()
#    3113 except dialect.dbapi.Error as e:
#    3114     if connection is None:
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:301, in Pool.connect(self)
#     293 def connect(self):
#     294     """Return a DBAPI connection from the pool.
#     295
#     296     The connection is instrumented such that when its
#    (...)
#     299
#     300     """
# --> 301     return _ConnectionFairy._checkout(self)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:748, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     745 @classmethod
#     746 def _checkout(cls, pool, threadconns=None, fairy=None):
#     747     if not fairy:
# --> 748         fairy = _ConnectionRecord.checkout(pool)
#     750         fairy._pool = pool
#     751         fairy._counter = 0
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:419, in _ConnectionRecord.checkout(cls, pool)
#     417 @classmethod
#     418 def checkout(cls, pool):
# --> 419     rec = pool._do_get()
#     420     try:
#     421         dbapi_connection = rec.get_connection()
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:144, in QueuePool._do_get(self)
#     142         return self._create_connection()
#     143     except:
# --> 144         with util.safe_reraise():
#     145             self._dec_overflow()
#     146 else:
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     195     exception.__cause__ = replace_context
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#     203     del exception, replace_context, from_, with_traceback
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/impl.py:142, in QueuePool._do_get(self)
#     140 if self._inc_overflow():
#     141     try:
# --> 142         return self._create_connection()
#     143     except:
#     144         with util.safe_reraise():
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:247, in Pool._create_connection(self)
#     244 def _create_connection(self):
#     245     """Called by subclasses to create a new ConnectionRecord."""
# --> 247     return _ConnectionRecord(self)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:362, in _ConnectionRecord.__init__(self, pool, connect)
#     360 self.__pool = pool
#     361 if connect:
# --> 362     self.__connect(first_connect_check=True)
#     363 self.finalize_callback = deque()
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:597, in _ConnectionRecord.__connect(self, first_connect_check)
#     595     self.fresh = True
#     596 except Exception as e:
# --> 597     with util.safe_reraise():
#     598         pool.logger.debug("Error on connect(): %s", e)
#     599 else:
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/util/compat.py:198, in raise_(***failed resolving arguments***)
#     195     exception.__cause__ = replace_context
#     197 try:
# --> 198     raise exception
#     199 finally:
#     200     # credit to
#     201     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     202     # as the __traceback__ object creates a cycle
#     203     del exception, replace_context, from_, with_traceback
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/pool/base.py:592, in _ConnectionRecord.__connect(self, first_connect_check)
#     590 try:
#     591     self.starttime = time.time()
# --> 592     connection = pool._invoke_creator(self)
#     593     pool.logger.debug("Created new connection %r", connection)
#     594     self.connection = connection
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/create.py:576, in create_engine.<locals>.connect(connection_record)
#     574         if connection is not None:
#     575             return connection
# --> 576 return dialect.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.12/site-packages/sqlalchemy/engine/default.py:548, in DefaultDialect.connect(self, *cargs, **cparams)
#     546 def connect(self, *cargs, **cparams):
#     547     # inherits the docstring from interfaces.Dialect.connect
# --> 548     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.12/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  database "GABE" does not exist
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# 2. **Handling the `... FATAL:  database "<DB_NAME>" does not exist` Error**
#
#     - If the connection attempt throws the following error:
#
#         ```python
#         ... FATAL:  database "<DB_NAME>" does not exist
#         ```
#
#         This means your database hasn't been created yet. To fix this, follow theses steps:
#
#     - Open your **terminal**
#
#     - Run the following command to create your database, making sure to replace `<DB_USER>` and `<DB_NAME>` with the values you set in your `.env` file:
#
#         ```python
#         createdb -h localhost -U <DB_USER> <DB_NAME>
#         ```
#
#         For example, if you set `DB_USER` to `gitpod` and `DB_NAME` to `marisols_database`, the command would be:
#
#         ```python
#         createdb -h localhost -U gitpod marisols_database
#         ```
#
#     - If prompted, enter the password you set in your `.env` file for the `DB_USER`
#
#     - Rerun the code cell above. If successfull, the output will be `Starting the connection...`

# %% [markdown]
# ### Inspecting the Database for Tables
# Now that you've connected to the database, let's check whether any tables currently exist. Since you haven't created any tables yet, the output should be an empty list.
#
# `SQLAlchemy` provides a helpful function called `inspect` to examine the database. In this step, you'll use it to list all existing tables in the database.
#
# Run the following code to inspect the database:

# %%
# We can inspect our database by creating an inspector object
inspector = inspect(engine)

# Get the table names
table_names = inspector.get_table_names()

# Print the table names
print(f"Existing tables in the database: {table_names}")

# %% [markdown]
# Since the database is currently empty (you haven’t created any tables yet).

# %% [markdown]
# ### Creating Tables in the Database
# We need to create four tables: `publishers`, `authors`, `books`, and `book_authors`, with foreign key relationships between them. These relationships will help organize the data logically and maintain integrity.
#
# - **Check if a table exists**: To avoid errors from trying to create a table that already exists, we use `CREATE TABLE IF NOT EXISTS`. This ensures that the table is created only if it doesn't already exist in the database.
#
# Run the following code to create the tables:

# %%
from sqlalchemy import text

# Connect to the database
with engine.begin() as connection:
    # Execute the SQL statements to create tables
    connection.execute(text("""
    CREATE TABLE IF NOT EXISTS publishers(
        publisher_id INT NOT NULL,
        name VARCHAR(255) NOT NULL,
        PRIMARY KEY(publisher_id)
    );

    CREATE TABLE IF NOT EXISTS authors(
        author_id INT NOT NULL,
        first_name VARCHAR(100) NOT NULL,
        middle_name VARCHAR(50) NULL,
        last_name VARCHAR(100) NULL,
        PRIMARY KEY(author_id)
    );

    CREATE TABLE IF NOT EXISTS books(
        book_id INT NOT NULL,
        title VARCHAR(255) NOT NULL,
        total_pages INT NULL,
        rating DECIMAL(4, 2) NULL,
        isbn VARCHAR(13) NULL,
        published_date DATE,
        publisher_id INT NULL,
        PRIMARY KEY(book_id),
        CONSTRAINT fk_publisher FOREIGN KEY(publisher_id) REFERENCES publishers(publisher_id)
    );

    CREATE TABLE IF NOT EXISTS book_authors (
        book_id INT NOT NULL,
        author_id INT NOT NULL,
        PRIMARY KEY(book_id, author_id),
        CONSTRAINT fk_book FOREIGN KEY(book_id) REFERENCES books(book_id) ON DELETE CASCADE,
        CONSTRAINT fk_author FOREIGN KEY(author_id) REFERENCES authors(author_id) ON DELETE CASCADE
    );
    """))

# %% [markdown]
# After running the SQL statements, you can re-inspect the database to confirm that the tables were created successfully:

# %%
# Let's inspect out database again to confirm that the tables were created
inspector = inspect(engine)

# Get the table names
table_names = inspector.get_table_names()

# Print the table names
print(f"Existing tables in the database: {table_names}")
# Out:
# Existing tables in the database: ['publishers', 'books', 'book_authors', 'authors']

# %% [markdown]
# ### Inserting Data into the Tables
# Now you will insert sample data into the tables you created earlier: `publishers`, `authors`, `books`, and `book_authors`. This will allow you to work with real data in your database for further queries and analyses.

# %%
# Execute the SQL sentences to insert data into tables
with engine.begin() as connection:
    connection.execute(text("""
    INSERT INTO publishers(publisher_id, name) VALUES (1, 'O Reilly Media');
    INSERT INTO publishers(publisher_id, name) VALUES (2, 'A Book Apart');
    INSERT INTO publishers(publisher_id, name) VALUES (3, 'A K PETERS');
    INSERT INTO publishers(publisher_id, name) VALUES (4, 'Academic Press');
    INSERT INTO publishers(publisher_id, name) VALUES (5, 'Addison Wesley');
    INSERT INTO publishers(publisher_id, name) VALUES (6, 'Albert&Sweigart');
    INSERT INTO publishers(publisher_id, name) VALUES (7, 'Alfred A. Knopf');

    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (1, 'Merritt', null, 'Eric');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (2, 'Linda', null, 'Mui');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (3, 'Alecos', null, 'Papadatos');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (4, 'Anthony', null, 'Molinaro');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (5, 'David', null, 'Cronin');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (6, 'Richard', null, 'Blum');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (7, 'Yuval', 'Noah', 'Harari');
    INSERT INTO authors (author_id, first_name, middle_name, last_name) VALUES (8, 'Paul', null, 'Albitz');

    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (1, 'Lean Software Development: An Agile Toolkit', 240, 4.17, '9780320000000', '2003-05-18', 5);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (2, 'Facing the Intelligence Explosion', 91, 3.87, null, '2013-02-01', 7);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (3, 'Scala in Action', 419, 3.74, '9781940000000', '2013-04-10', 1);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (4, 'Patterns of Software: Tales from the Software Community', 256, 3.84, '9780200000000', '1996-08-15', 1);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (5, 'Anatomy Of LISP', 446, 4.43, '9780070000000', '1978-01-01', 3);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (6, 'Computing machinery and intelligence', 24, 4.17, null, '2009-03-22', 4);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (7, 'XML: Visual QuickStart Guide', 269, 3.66, '9780320000000', '2009-01-01', 5);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (8, 'SQL Cookbook', 595, 3.95, '9780600000000', '2005-12-01', 7);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (9, 'The Apollo Guidance Computer: Architecture And Operation (Springer Praxis Books / Space Exploration)', 439, 4.29, '9781440000000', '2010-07-01', 6);
    INSERT INTO books (book_id, title, total_pages, rating, isbn, published_date, publisher_id) VALUES (10, 'Minds and Computers: An Introduction to the Philosophy of Artificial Intelligence', 222, 3.54, '9780750000000', '2007-02-13', 7);

    INSERT INTO book_authors (book_id, author_id) VALUES (1, 1);
    INSERT INTO book_authors (book_id, author_id) VALUES (2, 8);
    INSERT INTO book_authors (book_id, author_id) VALUES (3, 7);
    INSERT INTO book_authors (book_id, author_id) VALUES (4, 6);
    INSERT INTO book_authors (book_id, author_id) VALUES (5, 5);
    INSERT INTO book_authors (book_id, author_id) VALUES (6, 4);
    INSERT INTO book_authors (book_id, author_id) VALUES (7, 3);
    INSERT INTO book_authors (book_id, author_id) VALUES (8, 2);
    INSERT INTO book_authors (book_id, author_id) VALUES (9, 4);
    INSERT INTO book_authors (book_id, author_id) VALUES (10, 1);
    """))

# %% [markdown]
# ### Load SQL Tables into Pandas DataFrames
# We will use the `pandas` library to read the data from the SQL tables we created and inserted data into in the previous step. The `pd.read_sql` function allows us to execute SQL queries and return the results as pandas DataFrames.
#
# This is useful for analyzing and manipulating the data programmatically. Below are the commands to load each table into its respective DataFrame:

# %%
# Use pandas to print one of the tables as dataframe using read_sql function
# Here we are reading the publishers table as a pandas dataframe
publishers_df = pd.read_sql("SELECT * FROM publishers;", engine)
publishers_df
# Out:
#    publisher_id             name
# 0             1   O Reilly Media
# 1             2     A Book Apart
# 2             3       A K PETERS
# 3             4   Academic Press
# 4             5   Addison Wesley
# 5             6  Albert&Sweigart
# 6             7  Alfred A. Knopf

# %%
# authors table
authors_df = pd.read_sql("SELECT * FROM authors;", engine)
authors_df
# Out:
#    author_id first_name middle_name  last_name
# 0          1    Merritt        None       Eric
# 1          2      Linda        None        Mui
# 2          3     Alecos        None  Papadatos
# 3          4    Anthony        None   Molinaro
# 4          5      David        None     Cronin
# 5          6    Richard        None       Blum
# 6          7      Yuval        Noah     Harari
# 7          8       Paul        None     Albitz

# %%
# books table
books_df = pd.read_sql("SELECT * FROM books;", engine)
books_df
# Out:
#    book_id                                              title  total_pages  \
# 0        1        Lean Software Development: An Agile Toolkit          240
# 1        2                  Facing the Intelligence Explosion           91
# 2        3                                    Scala in Action          419
# 3        4  Patterns of Software: Tales from the Software ...          256
# 4        5                                    Anatomy Of LISP          446
# 5        6               Computing machinery and intelligence           24
# 6        7                       XML: Visual QuickStart Guide          269
# 7        8                                       SQL Cookbook          595
# 8        9  The Apollo Guidance Computer: Architecture And...          439
# 9       10  Minds and Computers: An Introduction to the Ph...          222
#
#    rating           isbn published_date  publisher_id
# 0    4.17  9780320000000     2003-05-18             5
# 1    3.87           None     2013-02-01             7
# 2    3.74  9781940000000     2013-04-10             1
# 3    3.84  9780200000000     1996-08-15             1
# 4    4.43  9780070000000     1978-01-01             3
# 5    4.17           None     2009-03-22             4
# 6    3.66  9780320000000     2009-01-01             5
# 7    3.95  9780600000000     2005-12-01             7
# 8    4.29  9781440000000     2010-07-01             6
# 9    3.54  9780750000000     2007-02-13             7

# %%
# book_authors table
book_authors_df = pd.read_sql("SELECT * FROM book_authors;", engine)
book_authors_df
# Out:
#    book_id  author_id
# 0        1          1
# 1        2          8
# 2        3          7
# 3        4          6
# 4        5          5
# 5        6          4
# 6        7          3
# 7        8          2
# 8        9          4
# 9       10          1

# %% [markdown]
# ## SQL Data Exploration and Analysis
# In this section, you will complete 15 exercises that require you to write SQL queries to extract insights from the `publishers`, `authors`, `books`, and `book_authors` tables.
#
# Read each prompt carefully, then write and execute the appropriate SQL query using the provided SQLAlchemy `engine`. Aim to complete all exercises to enhance your SQL skills and deepen your understanding of data manipulation.

# %%
# 1. Write a SQL query to select all columns and rows from the `books` table. 
# (Hint: Use `*`)
all_books = pd.read_sql("SELECT * FROM books", engine)
all_books
# Out:
#    book_id                                              title  total_pages  \
# 0        1        Lean Software Development: An Agile Toolkit          240
# 1        2                  Facing the Intelligence Explosion           91
# 2        3                                    Scala in Action          419
# 3        4  Patterns of Software: Tales from the Software ...          256
# 4        5                                    Anatomy Of LISP          446
# 5        6               Computing machinery and intelligence           24
# 6        7                       XML: Visual QuickStart Guide          269
# 7        8                                       SQL Cookbook          595
# 8        9  The Apollo Guidance Computer: Architecture And...          439
# 9       10  Minds and Computers: An Introduction to the Ph...          222
#
#    rating           isbn published_date  publisher_id
# 0    4.17  9780320000000     2003-05-18             5
# 1    3.87           None     2013-02-01             7
# 2    3.74  9781940000000     2013-04-10             1
# 3    3.84  9780200000000     1996-08-15             1
# 4    4.43  9780070000000     1978-01-01             3
# 5    4.17           None     2009-03-22             4
# 6    3.66  9780320000000     2009-01-01             5
# 7    3.95  9780600000000     2005-12-01             7
# 8    4.29  9781440000000     2010-07-01             6
# 9    3.54  9780750000000     2007-02-13             7

# %%
# 2. Write a SQL query to select the first 3 rows from the `books` table. 
# (Hint: Use `LIMIT n` where n is the number of rows)
top_three_rows = pd.read_sql("SELECT * FROM books LIMIT 3;", engine)
top_three_rows
# Out:
#    book_id                                        title  total_pages  rating  \
# 0        1  Lean Software Development: An Agile Toolkit          240    4.17
# 1        2            Facing the Intelligence Explosion           91    3.87
# 2        3                              Scala in Action          419    3.74
#
#             isbn published_date  publisher_id
# 0  9780320000000     2003-05-18             5
# 1           None     2013-02-01             7
# 2  9781940000000     2013-04-10             1

# %%
# 3. Write a SQL query to select only the `first_name` column of the `authors` table`.
authors_first_names = pd.read_sql("SELECT first_name FROM authors", engine)
authors_first_names
# Out:
#   first_name
# 0    Merritt
# 1      Linda
# 2     Alecos
# 3    Anthony
# 4      David
# 5    Richard
# 6      Yuval
# 7       Paul

# %%
# 4. Write a SQL query to to select only the `title` column of the `books` table`.
book_titles = pd.read_sql("SELECT first_name FROM authors;", engine)
book_titles
# Out:
#   first_name
# 0    Merritt
# 1      Linda
# 2     Alecos
# 3    Anthony
# 4      David
# 5    Richard
# 6      Yuval
# 7       Paul

# %%
# 5. Write a SQL query to select only the `name` column of the `publishers` table`.
publishers = pd.read_sql("SELECT name FROM publishers", engine)
publishers
# Out:
#               name
# 0   O Reilly Media
# 1     A Book Apart
# 2       A K PETERS
# 3   Academic Press
# 4   Addison Wesley
# 5  Albert&Sweigart
# 6  Alfred A. Knopf

# %%
# 6. Write a SQL query to select the `title` and `published_date` columns of the `books` table`.
book_dates = pd.read_sql("SELECT published_date FROM books", engine)
book_dates
# Out:
#   published_date
# 0     2003-05-18
# 1     2013-02-01
# 2     2013-04-10
# 3     1996-08-15
# 4     1978-01-01
# 5     2009-03-22
# 6     2009-01-01
# 7     2005-12-01
# 8     2010-07-01
# 9     2007-02-13

# %%
# 7. Write a SQL query to count the number of rows listed in the `authors` table. 
# (Hint: Use the `COUNT()` command)
row_count = pd.read_sql("SELECT COUNT(*) FROM authors", engine)
row_count
# Out:
#    count
# 0      8

# %%
# 8. Write a SQL query to find the sum of `total_pages` using the `books` table. 
# (Hint: Use the `SUM()` command)
sum_total_pages = pd.read_sql("SELECT SUM(total_pages) FROM books", engine)
sum_total_pages
# Out:
#     sum
# 0  3001

# %%
# 9. Write a SQL query to find the average book `rating` using the `books` table. 
# (Hint: Use the `AVG()` command)
avg_rating = pd.read_sql("books", engine)
avg_rating
# Out:
#    book_id                                              title  total_pages  \
# 0        1        Lean Software Development: An Agile Toolkit          240
# 1        2                  Facing the Intelligence Explosion           91
# 2        3                                    Scala in Action          419
# 3        4  Patterns of Software: Tales from the Software ...          256
# 4        5                                    Anatomy Of LISP          446
# 5        6               Computing machinery and intelligence           24
# 6        7                       XML: Visual QuickStart Guide          269
# 7        8                                       SQL Cookbook          595
# 8        9  The Apollo Guidance Computer: Architecture And...          439
# 9       10  Minds and Computers: An Introduction to the Ph...          222
#
#    rating           isbn published_date  publisher_id
# 0    4.17  9780320000000     2003-05-18             5
# 1    3.87           None     2013-02-01             7
# 2    3.74  9781940000000     2013-04-10             1
# 3    3.84  9780200000000     1996-08-15             1
# 4    4.43  9780070000000     1978-01-01             3
# 5    4.17           None     2009-03-22             4
# 6    3.66  9780320000000     2009-01-01             5
# 7    3.95  9780600000000     2005-12-01             7
# 8    4.29  9781440000000     2010-07-01             6
# 9    3.54  9780750000000     2007-02-13             7

# %%
# 10. Write a SQL query to find the minimum book `rating` using the `books` table. 
# (Hint: Use the `MIN()` command)
min_rating = pd.read_sql("SELECT AVG(rating) FROM books;", engine)
min_rating
# Out:
#      avg
# 0  3.966

# %%
# 11. Write a SQL query to find the maximum book `rating` using the `books` table. 
# (Hint: Use the `MAX()` command)
max_rating = pd.read_sql("SELECT MAX(rating) FROM books", engine)
max_rating
# Out:
#     max
# 0  4.43

# %%
# 12. Write a SQL query to list the rows in the `books` table where `isbn` is not None. 
# (Hint: Use the `WHERE()` command)
non_null_isbn_rows = pd.read_sql("SELECT * FROM books WHERE isbn IS NOT NULL", engine)
non_null_isbn_rows
# Out:
#    book_id                                              title  total_pages  \
# 0        1        Lean Software Development: An Agile Toolkit          240
# 1        3                                    Scala in Action          419
# 2        4  Patterns of Software: Tales from the Software ...          256
# 3        5                                    Anatomy Of LISP          446
# 4        7                       XML: Visual QuickStart Guide          269
# 5        8                                       SQL Cookbook          595
# 6        9  The Apollo Guidance Computer: Architecture And...          439
# 7       10  Minds and Computers: An Introduction to the Ph...          222
#
#    rating           isbn published_date  publisher_id
# 0    4.17  9780320000000     2003-05-18             5
# 1    3.74  9781940000000     2013-04-10             1
# 2    3.84  9780200000000     1996-08-15             1
# 3    4.43  9780070000000     1978-01-01             3
# 4    3.66  9780320000000     2009-01-01             5
# 5    3.95  9780600000000     2005-12-01             7
# 6    4.29  9781440000000     2010-07-01             6
# 7    3.54  9780750000000     2007-02-13             7

# %%
# 13. Write a SQL query to list the rows in the `books` table where `total_pages` is greater than 400. 
# (Hint: Use the `WHERE()` command)
large_books = pd.read_sql("SELECT * FROM books WHERE total_pages > 400", engine)
large_books
# Out:
#    book_id                                              title  total_pages  \
# 0        3                                    Scala in Action          419
# 1        5                                    Anatomy Of LISP          446
# 2        8                                       SQL Cookbook          595
# 3        9  The Apollo Guidance Computer: Architecture And...          439
#
#    rating           isbn published_date  publisher_id
# 0    3.74  9781940000000     2013-04-10             1
# 1    4.43  9780070000000     1978-01-01             3
# 2    3.95  9780600000000     2005-12-01             7
# 3    4.29  9781440000000     2010-07-01             6

# %%
# 14. Write a SQL query to list the rows in the `books` table where `published_date` is before 2000-01-01. 
# (Hint: Use the `WHERE()` command)
old_books = pd.read_sql("SELECT * FROM books WHERE published_date < '2000-01-01'", engine)
old_books
# Out:
#    book_id                                              title  total_pages  \
# 0        4  Patterns of Software: Tales from the Software ...          256
# 1        5                                    Anatomy Of LISP          446
#
#    rating           isbn published_date  publisher_id
# 0    3.84  9780200000000     1996-08-15             1
# 1    4.43  9780070000000     1978-01-01             3

# %%
# 15. Write a SQL query to list the book titles along with the first name of the author. 
# (Hint: Several JOINs may be needed)

book_info = pd.read_sql(
    """
    SELECT books.title, authors.first_name
    FROM books
    JOIN book_authors ON books.book_id = book_authors.book_id
    JOIN authors ON authors.author_id = book_authors.author_id
    """,
    engine
)

book_info
# Out:
#                                                title first_name
# 0        Lean Software Development: An Agile Toolkit    Merritt
# 1                  Facing the Intelligence Explosion       Paul
# 2                                    Scala in Action      Yuval
# 3  Patterns of Software: Tales from the Software ...    Richard
# 4                                    Anatomy Of LISP      David
# 5               Computing machinery and intelligence    Anthony
# 6                       XML: Visual QuickStart Guide     Alecos
# 7                                       SQL Cookbook      Linda
# 8  The Apollo Guidance Computer: Architecture And...    Anthony
# 9  Minds and Computers: An Introduction to the Ph...    Merritt

# %% [markdown]
# ## How to clear the database

# %%
# Let's clear our database by dropping all our tables
with engine.begin() as connection:
    connection.execute(text("""
        DROP TABLE book_authors;

        DROP TABLE books;

        DROP TABLE authors;

        DROP TABLE publishers;
        """))

# %%
# Let's inspect out database again to confirm that the tables were deleted
inspector = inspect(engine)

# Get the table names
table_names = inspector.get_table_names()

# Print the table names
print(f"Existing tables in the database: {table_names}")
# Out:
# Existing tables in the database: []
